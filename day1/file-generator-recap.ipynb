# %%
import os

def file_line_generator(folder_path):
    """
    Generator that yields lines from all files inside a folder
    one line at a time (lazy loading).
    """
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        print ("file path", file_path)

        if os.path.isfile(file_path):
            print ("reading file", file_path)

            with open(file_path, 'r') as f:
                for line in f:
                    print (file_path, line)
                    yield line.strip()

# %%
gen = file_line_generator("data")

# %%
print(next(gen))
# Out:
# file path data\movies1.csv
# reading file data\movies1.csv
# data\movies1.csv 1,Toy Story (1995),Adventure|Animation|Children|Comedy|Fantasy
#
# 1,Toy Story (1995),Adventure|Animation|Children|Comedy|Fantasy

# %%
print(next(gen))
# Out:
# data\movies1.csv 2,Jumanji (1995),Adventure|Children|Fantasy
#
# 2,Jumanji (1995),Adventure|Children|Fantasy

# %%
print(next(gen))
# Out:
# data\movies1.csv 3,Grumpier Old Men (1995),Comedy|Romance
#
# 3,Grumpier Old Men (1995),Comedy|Romance

# %%
print(next(gen))
# Out:
# data\movies1.csv 4,Waiting to Exhale (1995),Comedy|Drama|Romance
# 4,Waiting to Exhale (1995),Comedy|Drama|Romance

# %%
print(next(gen))
# Out:
# file path data\movies2.csv
# reading file data\movies2.csv
# data\movies2.csv 5,Father of the Bride Part II (1995),Comedy
#
# 5,Father of the Bride Part II (1995),Comedy
